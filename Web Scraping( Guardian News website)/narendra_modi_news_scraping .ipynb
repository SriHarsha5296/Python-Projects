# %% [markdown]
# importing libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# API KEY

# %%
API_KEY="6cb92289-3a28-404a-a85b-0cee72312917"

# %%
API_KEY

# %%
URL="https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=1"

# %%
URL_LIST=[]

# %%
for i in range (1,12):
    a= "https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page="
    b=str(i)
    c=a+b
    URL_LIST.append(c)

# %%
URL_LIST
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2023-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=6',
# ...

# %%
Info=[]

# %%
def json(URL1):
    response= requests.get(URL)
    X=response.json()
    Info.append(X)

# %%
output=[json(URL1) for URL1 in URL_LIST]

# %%
Info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 109,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 11,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/2024/apr/05/india-appears-to-confirm-extrajudicial-killings-in-pakistan',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-04-05T15:40:16Z',
#      'webTitle': 'India appears to confirm extrajudicial killings in Pakistan',
#      'webUrl': 'https://www.theguardian.com/world/2024/apr/05/india-appears-to-confirm-extrajudicial-killings-in-pakistan',
# ...

# %% [markdown]
# length

# %%
len(Info)
# Out:
# 11

# %% [markdown]
# total pages

# %%
Info[0]['response']['pages']
# Out:
# 11

# %% [markdown]
# toatal articals

# %%
Info[0]['response']['total']
# Out:
# 109

# %% [markdown]
# start from pages within  response within results within title

# %%
Info[0]['response']['results'][9]['webTitle']
# Out:
# 'As petals rained down and celebrities beamed, Modi unveiled his vision of a Hindu India | Mukul Kesavan'

# %%
FinalList=[]

# %%
try:
    for k in range(0,11):
        for j in range(0,10):
            value=dict(webtitles=Info[k]['response']['results'][j]['webTitle'],
        sectionname=Info[k]['response']['results'][j]['sectionName'],
        publisheddate=Info[k]['response']['results'][j]['webPublicationDate'],
        weburl=Info[k]['response']['results'][j]['webUrl'])
            FinalList.append(value)
except IndexError:
    print("Not Applicable")

# %%
FinalList
# Out:
# [{'webtitles': 'India appears to confirm extrajudicial killings in Pakistan',
#   'sectionname': 'World news',
#   'publisheddate': '2024-04-05T15:40:16Z',
#   'weburl': 'https://www.theguardian.com/world/2024/apr/05/india-appears-to-confirm-extrajudicial-killings-in-pakistan'},
#  {'webtitles': 'Arvind Kejriwal: the Delhi chief minister jailed by Modi’s government',
#   'sectionname': 'World news',
#   'publisheddate': '2024-03-28T18:10:52Z',
#   'weburl': 'https://www.theguardian.com/world/2024/mar/28/arvind-kejriwal-delhi-chief-minister-anti-corruption-jailed'},
#  {'webtitles': '‘Brazen propaganda’: pro-Modi films flood Bollywood before India election',
#   'sectionname': 'Film',
#   'publisheddate': '2024-03-22T11:32:51Z',
#   'weburl': 'https://www.theguardian.com/film/2024/mar/22/brazen-propaganda-pro-modi-films-flood-bollywood-before-india-election'},
#  {'webtitles': 'Who congratulated Putin on his election victory and what does it say about global alliances?',
# ...

# %% [markdown]
# Creating the data into dataframe

# %%
dataframe= pd.DataFrame(FinalList)

# %%
dataframe
# Out:
#                                              webtitles sectionname  \
# 0    India appears to confirm extrajudicial killing...  World news
# 1    Arvind Kejriwal: the Delhi chief minister jail...  World news
# 2    ‘Brazen propaganda’: pro-Modi films flood Boll...        Film
# 3    Who congratulated Putin on his election victor...  World news
# 4    Narendra Modi’s BJP given £570m under scheme a...  World news
# ..                                                 ...         ...
# 105  Narendra Modi visits Kashmir for first time si...  World news
# 106  ‘Why are you asleep?’ Rahul Gandhi pleads with...  World news
# 107  India confronts Google over Gemini AI tool’s ‘...  World news
# 108  The Guardian view on Modi in Ayodhya: an alarm...     Opinion
# 109  As petals rained down and celebrities beamed, ...     Opinion
#
#             publisheddate                                             weburl
# 0    2024-04-05T15:40:16Z  https://www.theguardian.com/world/2024/apr/05/...
# ...
